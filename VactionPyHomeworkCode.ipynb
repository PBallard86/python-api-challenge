# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup

import hvplot.pandas
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import cartopy
import geoviews
import json

# Import API key
from api_keys import geoapify_key
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  port mathurin -19.6833   63.4167     23.73        80           8
# 1        1         nemuro  43.3236  145.5750     13.09        66          33
# 2        2     queenstown -31.8976   26.8753     11.50        78           0
# 3        3  atafu village  -8.5421 -172.5159     28.46        73          97
# 4        4         lompoc  34.6391 -120.4579     28.90        77          75
#
#    Wind Speed Country        Date
# 0        3.80      MU  1697586269
# 1        8.38      JP  1697586269
# 2        0.94      ZA  1697586269
# 3        3.18      TK  1697586269
# 4        7.60      US  1697586269

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_humidity = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "CartoDark",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = .5,
    color = "City"
)

# Display the map
map_plot_humidity
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# ChatGPT
ideal_city_data_df = city_data_df[(city_data_df["Humidity"] < 55) & (city_data_df["Max Temp"] < 27)]

# Drop any rows with null values
# https://github.com/pandas-dev/pandas/blob/main/doc/cheatsheet/Pandas_Cheat_Sheet.pdf
ideal_city_data_df.dropna()

# Display sample data
ideal_city_data_df# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df[ (city_data_df["Max Temp"] >= 22) &  (city_data_df["Humidity"] <= 60) ]
clean_ideal_city_df = ideal_df[ ideal_df["Cloudiness"] == 0 ] 

# Drop any rows with null values
clean_ideal_data_df = clean_ideal_city_df.dropna()

# Display sample data
clean_ideal_data_df
# Out:
#      City_ID                         City      Lat       Lng  Max Temp  \
# 15        15                haiku-pauwela  20.9219 -156.3051     30.01
# 29        29               cabo san lucas  22.8909 -109.9124     34.23
# 112      112                 san patricio  28.0170  -97.5169     24.40
# 137      137                   siwa oasis  29.2041   25.5195     22.34
# 148      148                    carnarvon -24.8667  113.6333     24.48
# 182      182                        crane  31.3974 -102.3501     23.41
# 184      184                 port augusta -32.5000  137.7667     23.53
# 194      194                     ad dilam  23.9915   47.1627     26.23
# 281      281                     karratha -20.7377  116.8463     31.03
# 296      296                     saltillo  25.4167 -101.0000     23.29
# 339      339                      paulden  34.8856 -112.4682     29.95
# 366      366                        raton  36.9034 -104.4391     26.34
# 463      463                south hedland -20.4089  118.5983     31.96
# 485      485                       safaga  26.7292   33.9365     26.15
# 540      540               hassi messaoud  31.6804    6.0729     24.92
# 549      549                     amarillo  35.2220 -101.8313     27.88
# 550      550  cuatro cienegas de carranza  26.9833 -102.0833     23.01
# 553      553                santa barbara  34.7333 -120.0343     25.19
# 554      554                 port hedland -20.3167  118.5667     32.03
# 565      565                      mendota  36.7536 -120.3816     29.15
# 567      567                       zapata  26.9073  -99.2714     26.06
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 15         48           0        3.60      US  1697586270
# 29         51           0        2.06      MX  1697585880
# 112        39           0        3.40      US  1697586280
# 137        57           0        2.49      EG  1697586283
# 148        36           0        9.10      AU  1697586284
# 182        27           0        7.34      US  1697586288
# 184        19           0        2.13      AU  1697586288
# 194        49           0        1.88      SA  1697586289
# 281        18           0        2.71      AU  1697586298
# 296        45           0        4.12      MX  1697585912
# 339        17           0        1.34      US  1697586305
# 366        12           0        2.57      US  1697586309
# 463        11           0        3.09      AU  1697586320
# 485        45           0        4.47      EG  1697586322
# 540        23           0        2.57      DZ  1697586329
# 549        30           0        8.75      US  1697586184
# 550        34           0        2.72      MX  1697586330
# 553        47           0        5.66      US  1697586145
# 554        11           0        3.09      AU  1697586330
# 565        25           0        3.70      US  1697586332
# 567        25           0        2.06      US  1697586332

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = clean_ideal_data_df[['City','Country','Lat','Lng','Humidity']].copy()
hotel_df['Hotel Name'] = ""
hotel_df
# Out:
#                             City Country      Lat       Lng  Humidity  \
# 15                 haiku-pauwela      US  20.9219 -156.3051        48
# 29                cabo san lucas      MX  22.8909 -109.9124        51
# 112                 san patricio      US  28.0170  -97.5169        39
# 137                   siwa oasis      EG  29.2041   25.5195        57
# 148                    carnarvon      AU -24.8667  113.6333        36
# 182                        crane      US  31.3974 -102.3501        27
# 184                 port augusta      AU -32.5000  137.7667        19
# 194                     ad dilam      SA  23.9915   47.1627        49
# 281                     karratha      AU -20.7377  116.8463        18
# 296                     saltillo      MX  25.4167 -101.0000        45
# 339                      paulden      US  34.8856 -112.4682        17
# 366                        raton      US  36.9034 -104.4391        12
# 463                south hedland      AU -20.4089  118.5983        11
# 485                       safaga      EG  26.7292   33.9365        45
# 540               hassi messaoud      DZ  31.6804    6.0729        23
# 549                     amarillo      US  35.2220 -101.8313        30
# 550  cuatro cienegas de carranza      MX  26.9833 -102.0833        34
# 553                santa barbara      US  34.7333 -120.0343        47
# 554                 port hedland      AU -20.3167  118.5667        11
# 565                      mendota      US  36.7536 -120.3816        25
# 567                       zapata      US  26.9073  -99.2714        25
#
#     Hotel Name
# 15
# 29
# 112
# 137
# 148
# 182
# 184
# 194
# 281
# 296
# 339
# 366
# 463
# 485
# 540
# 549
# 550
# 553
# 554
# 565
# 567

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
# ChatGPT

categories = "accommodation.hotel"
limit = 20
radius = 10000
params = {
    "categories":categories,
    "limit":limit,
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lng = row["Lng"]
    lat = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    # Convert the API response to JSON format
    name_address = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data# Set parameters to search for a hotel

radius = 10000
categories = 'accommodation.hotel'
limit = 1
params = {
    "categories":categories,
    "limit":limit,
    "apiKey":geoapify_key    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    city_lat = row.loc['Lat']
    city_lng = row.loc['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    filter = f"circle:{city_lng},{city_lat},{radius}"
    bias = f"proximity:{city_lng},{city_lat}"
    params["filter"] = filter
    params["bias"] = bias
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
hotel_df
# Out:
# Starting hotel search
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# cabo san lucas - nearest hotel: Comfort Rooms
# san patricio - nearest hotel: No hotel found
# siwa oasis - nearest hotel: فندق الكيلانى
# carnarvon - nearest hotel: No hotel found
# crane - nearest hotel: No hotel found
# port augusta - nearest hotel: Hotel Commonwealth
# ad dilam - nearest hotel: No hotel found
# karratha - nearest hotel: Karratha International Hotel
# saltillo - nearest hotel: Hotel Colonial
# paulden - nearest hotel: No hotel found
# raton - nearest hotel: Travelodge
# south hedland - nearest hotel: Port Haven
# safaga - nearest hotel: Dolphin Hotel
# hassi messaoud - nearest hotel: AMC
# amarillo - nearest hotel: Embassy Suites
# cuatro cienegas de carranza - nearest hotel: No hotel found
# santa barbara - nearest hotel: No hotel found
# port hedland - nearest hotel: The Esplanade Hotel
# mendota - nearest hotel: No hotel found
# zapata - nearest hotel: No hotel found
# Starting hotel search
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# cabo san lucas - nearest hotel: Comfort Rooms
# san patricio - nearest hotel: No hotel found
# siwa oasis - nearest hotel: فندق الكيلانى
# carnarvon - nearest hotel: No hotel found
# crane - nearest hotel: No hotel found
# port augusta - nearest hotel: Hotel Commonwealth
# ad dilam - nearest hotel: No hotel found
# karratha - nearest hotel: Karratha International Hotel
# saltillo - nearest hotel: Hotel Colonial
# paulden - nearest hotel: No hotel found
# raton - nearest hotel: Travelodge
# south hedland - nearest hotel: Port Haven
# safaga - nearest hotel: Dolphin Hotel
# hassi messaoud - nearest hotel: AMC
# amarillo - nearest hotel: Embassy Suites
# cuatro cienegas de carranza - nearest hotel: No hotel found
# santa barbara - nearest hotel: No hotel found
# port hedland - nearest hotel: The Esplanade Hotel
# mendota - nearest hotel: No hotel found
# zapata - nearest hotel: No hotel found
#                             City Country      Lat       Lng  Humidity  \
# 15                 haiku-pauwela      US  20.9219 -156.3051        48
# 29                cabo san lucas      MX  22.8909 -109.9124        51
# 112                 san patricio      US  28.0170  -97.5169        39
# 137                   siwa oasis      EG  29.2041   25.5195        57
# 148                    carnarvon      AU -24.8667  113.6333        36
# 182                        crane      US  31.3974 -102.3501        27
# 184                 port augusta      AU -32.5000  137.7667        19
# 194                     ad dilam      SA  23.9915   47.1627        49
# 281                     karratha      AU -20.7377  116.8463        18
# 296                     saltillo      MX  25.4167 -101.0000        45
# 339                      paulden      US  34.8856 -112.4682        17
# 366                        raton      US  36.9034 -104.4391        12
# 463                south hedland      AU -20.4089  118.5983        11
# 485                       safaga      EG  26.7292   33.9365        45
# 540               hassi messaoud      DZ  31.6804    6.0729        23
# 549                     amarillo      US  35.2220 -101.8313        30
# 550  cuatro cienegas de carranza      MX  26.9833 -102.0833        34
# 553                santa barbara      US  34.7333 -120.0343        47
# 554                 port hedland      AU -20.3167  118.5667        11
# 565                      mendota      US  36.7536 -120.3816        25
# 567                       zapata      US  26.9073  -99.2714        25
#
#                        Hotel Name
# 15       Inn At Mama's Fish House
# 29                  Comfort Rooms
# 112                No hotel found
# 137                 فندق الكيلانى
# 148                No hotel found
# 182                No hotel found
# 184            Hotel Commonwealth
# 194                No hotel found
# 281  Karratha International Hotel
# 296                Hotel Colonial
# 339                No hotel found
# 366                    Travelodge
# 463                    Port Haven
# 485                 Dolphin Hotel
# 540                           AMC
# 549                Embassy Suites
# 550                No hotel found
# 553                No hotel found
# 554           The Esplanade Hotel
# 565                No hotel found
# 567                No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    color = "City",
    hover_cols = ['City','Humidity','Hotel Name','Country']
)
hvplot.save(map_plot_2, '../output_data/Hotels.html')

# Display the map
map_plot_2
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1112', ...)
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
